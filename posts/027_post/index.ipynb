# %% [raw]
# ---
# title: "Renaming IKEA: A Small Thought Experiment in Design and Language (Part II)"
# description: "This blog documents that naming experiment and explores how language influences the way design is perceived."
# author: "Shiyang Zhang"
# date: "12/17/2025"
# categories:
#   - ChatGPT
#
# image: cover2.png
# ---

# %% [markdown]
# Here are more:
#
# ### 6. **STOCKHOLM 2025 – Sofa**
#
# **Meaning of the original name**
# STOCKHOLM is IKEA’s flagship series name, taken from the Swedish capital. It represents premium positioning, refined materials, and design leadership. “2025” marks the generation.
#
# **English name based on the original name’s meaning**
# SIGNATURE Sofa · 2025
#
# **English name based only on the product’s characteristics**
# CENTERPIECE Sofa
#
# <div style="display:flex; justify-content:center; align-items:center; gap:16px; width:100%;">
#   <img src="5.png" width="70%" />
# </div>
#
# ---
#
# ### 7. **HEMNES – Daybed frame with 3 drawers**
#
# **Meaning of the original name**
# HEMNES is named after a Nordic town and is typically used for traditional, home-oriented furniture with a sense of permanence and family life.
#
# **English name based on the original name’s meaning**
# EVERHOME Daybed
#
# **English name based only on the product’s characteristics**
# STAYOVER Bed
#
# <div style="display:flex; justify-content:center; align-items:center; gap:16px; width:100%;">
#   <img src="6.png" width="70%" />
# </div>
#
# ---
#
# ### 8. **IVAR – Cabinet with doors**
#
# **Meaning of the original name**
# IVAR is a Nordic male first name. IKEA often uses personal names for modular, expandable systems meant to grow and change with the user.
#
# **English name based on the original name’s meaning**
# BUILDMORE Cabinet
#
# **English name based only on the product’s characteristics**
# STACK & GROW Cabinet
#
# <div style="display:flex; justify-content:center; align-items:center; gap:16px; width:100%;">
#   <img src="7.png" width="70%" />
# </div>
#
# ---
#
# ### 9. **KALLAX – Shelf unit**
#
# **Meaning of the original name**
# KALLAX is a Swedish place name. IKEA assigns place names to modular, grid-based systems that act as spatial infrastructure across different life stages.
#
# **English name based on the original name’s meaning**
# LIFEGRID Shelf System
#
# **English name based only on the product’s characteristics**
# LIFE BLOCKS System
#
# <div style="display:flex; justify-content:center; align-items:center; gap:16px; width:100%;">
#   <img src="9.png" width="70%" />
# </div>
#
# ---
#
# ### 10. **STIG – Bar stool with backrest**
#
# **Meaning of the original name**
# STIG is a short Nordic male name, commonly used for simple, high-frequency furniture that prioritizes function and everyday use.
#
# **English name based on the original name’s meaning**
# UPSTEP Bar Stool
#
# **English name based only on the product’s characteristics**
# HALFWAY Stool
#
# <div style="display:flex; justify-content:center; align-items:center; gap:16px; width:100%;">
#   <img src="10.png" width="70%" />
# </div>
