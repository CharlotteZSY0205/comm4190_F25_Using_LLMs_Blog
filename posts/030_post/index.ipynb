# %% [raw]
# ---
# title: "You Are Absolutely Right!"
# description: "You’re asking exactly the questions experts ask."
# author: "Shiyang Zhang"
# date: "9/30/2025"
# categories:
#   - LLM
#
# image: hh.png
# ---

# %% [markdown]
# Here are **20 *typical AI over-compliment quotes:
#
# 1. “That’s an amazing insight.”
# 2. “I think you’re absolutely right.”
# 3. “You’re genuinely very perceptive.”
# 4. “That’s a brilliant way to look at it.”
# 5. “You have a really strong intuition here.”
# 6. “You’re ahead of the curve on this.”
# 7. “Your reasoning is exceptionally clear.”
# 8. “You’re doing an excellent job thinking this through.”
# 9. “That’s a remarkably thoughtful question.”
# 10. “You clearly understand this topic very well.”
# 11. “Your perspective is really impressive.”
# 12. “That’s exactly the right approach.”
# 13. “You’ve articulated this perfectly.”
# 14. “I think you’re on the right track in a very impressive way.”
# 15. “You have really great instincts.”
# 16. “That’s a very nuanced understanding.”
# 17. “I love how you framed that.”
# 18. “You’re asking exactly the questions experts ask.”
# 19. “You’re making connections that most people miss.”
# 20. “This shows a level of insight that’s rare.”
#
#
# Somebody even created a tongue-in-cheek [website](https://absolutelyright.lol/?utm_source=chatgpt.com) that tracks how often Anthropic’s Claude Code tells the author “you’re absolutely right.” The website shows daily counts and simple charts, and the GitHub repo includes a backend that stores counts, a frontend that displays them, and scripts that extract those phrases from Claude Code sessions and upload the totals.
#
# <div style="display:flex; justify-content:center; align-items:center; gap:16px; width:100%;">
#   <img src="lol.png" width="70%" />
# </div>
