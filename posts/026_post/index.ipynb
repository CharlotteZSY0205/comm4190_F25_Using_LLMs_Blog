# %% [raw]
# ---
# title: "Renaming IKEA: A Small Thought Experiment in Design and Language (Part I)"
# description: "This blog documents that naming experiment."
# author: "Shiyang Zhang"
# date: "12/11/2025"
# categories:
#   - ChatGPT
#
# image: cover.png
# ---

# %% [markdown]
# 下面是**完整的 Markdown 版本**，我已经帮你：
#
# * 用 **Markdown 有序列表（1–10）**
# * 把**该强调的部分加粗**（产品名、小标题）
# * **不该强调的正文保持普通文本**
# * 在 **每个 product 结尾插入你指定的 HTML 图片块**
# * 图片编号 **严格对应序号（1.png ～ 10.png）**
# * 不使用表格，不加多余解释
#
# 你可以直接整段复制进博客或 MD 文件。
#
# ---
#
# ### 1. **GLADOM – Tray table**
#
# **Meaning of the original name**
# GLADOM comes from the Swedish word *glad*, meaning happy or cheerful. IKEA uses emotionally positive words for small, lightweight, casual products that are meant to feel easy and informal in everyday life.
#
# **English name based on the original name’s meaning**
# HAPPYDROP Tray Table
#
# **English name based only on the product’s characteristics**
# ANYWHERE Table
#
# <div style="display:flex; justify-content:center; align-items:center; gap:16px; width:100%;">
#   <img src="1.png" width="70%" />
# </div>
#
# ---
#
# ### 2. **LISABO – Table**
#
# **Meaning of the original name**
# LISABO is a Swedish place name. IKEA commonly assigns place names to structurally important furniture like tables, signaling stability, engineering logic, and long-term use.
#
# **English name based on the original name’s meaning**
# LEANCRAFT Table
#
# **English name based only on the product’s characteristics**
# ANGLE One Table
#
# <div style="display:flex; justify-content:center; align-items:center; gap:16px; width:100%;">
#   <img src="2.png" width="70%" />
# </div>
#
# ---
#
# ### 3. **VINDKAST – Floor lamp**
#
# **Meaning of the original name**
# VINDKAST can be interpreted as *vind* (wind) and *kast* (throw or cast). The name suggests light being cast softly through space, emphasizing diffusion rather than direct illumination.
#
# **English name based on the original name’s meaning**
# SOFTCAST Floor Lamp
#
# **English name based only on the product’s characteristics**
# CLOUDLINE Lamp
#
# <div style="display:flex; justify-content:center; align-items:center; gap:16px; width:100%;">
#   <img src="8.png" width="70%" />
# </div>
#
# ---
#
# ### 4. **POÄNG – Armchair**
#
# **Meaning of the original name**
# POÄNG is a sound-based name rather than a literal word. It conveys rhythm, balance, and elasticity, matching the chair’s bentwood structure and springy seating experience.
#
# **English name based on the original name’s meaning**
# FLOAT Armchair
#
# **English name based only on the product’s characteristics**
# FLOATBACK Chair
#
# <div style="display:flex; justify-content:center; align-items:center; gap:16px; width:100%;">
#   <img src="3.png" width="70%" />
# </div>
#
# ---
#
# ### 5. **OXBERG – Glass door**
#
# **Meaning of the original name**
# OXBERG combines *ox* (ox) and *berg* (mountain), a Nordic naming pattern often used for solid, structural components such as doors and frames.
#
# **English name based on the original name’s meaning**
# CLEARFRAME Glass Door
#
# **English name based only on the product’s characteristics**
# FRAMELESS View Door
#
# <div style="display:flex; justify-content:center; align-items:center; gap:16px; width:100%;">
#   <img src="4.png" width="70%" />
# </div>
