# %% [raw]
# ---
# title: "All I Want For Christmas Is You"
# description: "A festive Christmas tribute page with cozy styling, decorations, and centered lyrics."
# author: "Shiyang Zhang"
# date: "12/24/2025"
# categories:
#   - Christmas
#   - Music
#   - Web Design
# image: cover.jpg
# format:
#   html:
#     toc: false
# ---

# %% [markdown]
# <style>
#   :root {
#     --christmas-red: #c62828;
#     --christmas-red-dark: #8e0000;
#     --christmas-green: #2e7d32;
#     --christmas-gold: #ffd54f;
#     --snow-white: #fdfdfd;
#     --night-blue: #0b1020;
#     --soft-cream: #fffaf2;
#     --text-main: #fefefe;
#   }
#
#   body {
#     background: radial-gradient(circle at top, #ffecd2 0, #fcb69f 20%, #922b21 55%, #1b2735 100%);
#     font-family: "Georgia", "Times New Roman", serif;
#     color: var(--text-main);
#   }
#
#   .christmas-page {
#     min-height: 100vh;
#     display: flex;
#     flex-direction: column;
#     align-items: center;
#     justify-content: flex-start;
#     padding: 32px 16px 64px;
#     position: relative;
#     overflow: hidden;
#   }
#
#   /* soft falling snow */
#   .snowflake {
#     position: fixed;
#     top: -10px;
#     color: rgba(255, 255, 255, 0.8);
#     font-size: 10px;
#     pointer-events: none;
#     animation: snow-fall linear infinite;
#     z-index: -1;
#   }
#
#   @keyframes snow-fall {
#     0% { transform: translate3d(0, -10px, 0); opacity: 0; }
#     10% { opacity: 1; }
#     100% { transform: translate3d(-20px, 110vh, 0); opacity: 0; }
#   }
#
#   .christmas-header {
#     text-align: center;
#     max-width: 900px;
#     margin-bottom: 32px;
#     position: relative;
#   }
#
#   .christmas-header h1 {
#     font-size: clamp(2.6rem, 4vw, 3.4rem);
#     margin-bottom: 8px;
#     letter-spacing: 0.08em;
#     text-transform: uppercase;
#     color: var(--snow-white);
#     text-shadow: 0 0 12px rgba(0, 0, 0, 0.6);
#   }
#
#   .christmas-header .subtitle {
#     font-size: 1.05rem;
#     color: #ffe6e6;
#     margin-bottom: 20px;
#   }
#
#   .christmas-garland {
#     display: inline-flex;
#     align-items: center;
#     gap: 10px;
#     padding: 10px 18px;
#     border-radius: 999px;
#     background: linear-gradient(90deg, rgba(198,40,40,0.85), rgba(46,125,50,0.9));
#     box-shadow: 0 10px 24px rgba(0, 0, 0, 0.45);
#     margin-bottom: 16px;
#     border: 1px solid rgba(255, 255, 255, 0.4);
#   }
#
#   .garland-lights {
#     display: flex;
#     gap: 6px;
#   }
#
#   .garland-light {
#     width: 8px;
#     height: 14px;
#     border-radius: 8px;
#     background: var(--christmas-gold);
#     box-shadow: 0 0 10px rgba(255, 213, 79, 0.9);
#   }
#
#   .garland-label {
#     font-size: 0.85rem;
#     text-transform: uppercase;
#     letter-spacing: 0.18em;
#     color: #fff8e1;
#   }
#
#   .header-tags {
#     display: flex;
#     flex-wrap: wrap;
#     justify-content: center;
#     gap: 8px;
#     margin-top: 8px;
#   }
#
#   .header-tag {
#     font-size: 0.8rem;
#     padding: 4px 10px;
#     border-radius: 999px;
#     border: 1px solid rgba(255, 255, 255, 0.4);
#     background: rgba(11,16,32,0.35);
#     backdrop-filter: blur(8px);
#   }
#
#   .christmas-main {
#     width: 100%;
#     max-width: 960px;
#     display: grid;
#     grid-template-columns: minmax(0, 3fr) minmax(0, 2fr);
#     gap: 24px;
#   }
#
#   @media (max-width: 800px) {
#     .christmas-main {
#       grid-template-columns: minmax(0, 1fr);
#     }
#   }
#
#   .lyrics-card {
#     background: radial-gradient(circle at top left, rgba(255,255,255,0.28), rgba(255,255,255,0.06));
#     border-radius: 24px;
#     padding: 24px 24px 28px;
#     box-shadow:
#       0 20px 40px rgba(0, 0, 0, 0.4),
#       0 0 0 1px rgba(255, 255, 255, 0.12);
#     backdrop-filter: blur(18px);
#     border: 1px solid rgba(255, 255, 255, 0.3);
#     color: #1b1820;
#     background-clip: padding-box;
#   }
#
#   .lyrics-card h2 {
#     font-size: 1.4rem;
#     text-align: center;
#     margin-bottom: 8px;
#     color: var(--christmas-red-dark);
#   }
#
#   .lyrics-card .song-meta {
#     text-align: center;
#     font-size: 0.9rem;
#     color: #5d4037;
#     margin-bottom: 16px;
#   }
#
#   .lyrics-wrap {
#     text-align: center; /* center the lyrics text */
#     max-width: 640px;
#     margin: 0 auto;
#     font-size: 0.98rem;
#     line-height: 1.9;
#     color: #3e2723;
#   }
#
#   .lyrics-section-label {
#     text-transform: uppercase;
#     letter-spacing: 0.2em;
#     font-size: 0.74rem;
#     margin: 18px 0 6px;
#     color: var(--christmas-green);
#   }
#
#   .lyrics-line {
#     margin: 0;
#   }
#
#   .lyrics-note {
#     font-size: 0.8rem;
#     margin-top: 16px;
#     color: #6d4c41;
#   }
#
#   .side-panel {
#     display: flex;
#     flex-direction: column;
#     gap: 16px;
#   }
#
#   .character-row {
#     display: grid;
#     grid-template-columns: repeat(2, minmax(0, 1fr));
#     gap: 12px;
#   }
#
#   .character-card {
#     background: rgba(11, 16, 32, 0.85);
#     border-radius: 18px;
#     padding: 14px 14px 12px;
#     border: 1px solid rgba(255,255,255,0.16);
#     box-shadow: 0 10px 26px rgba(0, 0, 0, 0.55);
#   }
#
#   .character-badge {
#     width: 32px;
#     height: 32px;
#     border-radius: 50%;
#     background: radial-gradient(circle at 30% 30%, var(--christmas-gold), var(--christmas-red-dark));
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     font-size: 0.7rem;
#     color: #fff8e1;
#     margin-bottom: 6px;
#     box-shadow: 0 0 12px rgba(255,213,79,0.7);
#   }
#
#   .character-title {
#     font-size: 0.9rem;
#     font-weight: 600;
#     color: #ffebee;
#     margin-bottom: 4px;
#   }
#
#   .character-text {
#     font-size: 0.8rem;
#     color: #ffebee;
#     opacity: 0.83;
#   }
#
#   .cozy-footer {
#     margin-top: 18px;
#     font-size: 0.8rem;
#     color: #ffeae0;
#     text-align: center;
#   }
# </style>
#
# <!-- simple snowflakes (no emoji, just typographic symbols) -->
# <div class="snowflake" style="left: 5%; animation-duration: 14s; animation-delay: 0s;">*</div>
# <div class="snowflake" style="left: 20%; animation-duration: 17s; animation-delay: 1s;">*</div>
# <div class="snowflake" style="left: 40%; animation-duration: 13s; animation-delay: 2s;">*</div>
# <div class="snowflake" style="left: 60%; animation-duration: 18s; animation-delay: 0.5s;">*</div>
# <div class="snowflake" style="left: 80%; animation-duration: 15s; animation-delay: 1.5s;">*</div>
#
# <div class="christmas-page">
#   <header class="christmas-header">
#     <div class="christmas-garland">
#       <div class="garland-lights">
#         <div class="garland-light"></div>
#         <div class="garland-light" style="background: var(--christmas-green); box-shadow: 0 0 10px rgba(46,125,50,0.9);"></div>
#         <div class="garland-light"></div>
#         <div class="garland-light" style="background: #ff6f61; box-shadow: 0 0 10px rgba(255,111,97,0.9);"></div>
#       </div>
#       <span class="garland-label">cozy christmas listening</span>
#     </div>
#     <h1>All I Want For Christmas Is You</h1>
#     <p class="subtitle">A warm, glowing page for a classic Christmas love song.</p>
#     <div class="header-tags">
#       <span class="header-tag">Christmas Song</span>
#       <span class="header-tag">Holiday Mood</span>
#       <span class="header-tag">Cozy Night</span>
#     </div>
#   </header>
#
#   <main class="christmas-main">
#     <section class="lyrics-card">
#       <h2>Lyrics</h2>
#       <p class="song-meta">
#         A dedicated space for you to sing along and feel the holiday magic.
#       </p>
#
#       <div class="lyrics-wrap">
#         <p class="lyrics-section-label">[Intro]</p>
#         <p class="lyrics-line">< Put the intro lines of the song here ></p>
#
#         <p class="lyrics-section-label">[Verse 1]</p>
#         <p class="lyrics-line">< Paste the first verse here, one or two lines per paragraph ></p>
#         <p class="lyrics-line">< Continue the verse here... ></p>
#
#         <p class="lyrics-section-label">[Chorus]</p>
#         <p class="lyrics-line">< Paste the chorus lines here ></p>
#         <p class="lyrics-line">< Repeat or add more chorus lines... ></p>
#
#         <p class="lyrics-section-label">[Verse 2]</p>
#         <p class="lyrics-line">< Paste the second verse here ></p>
#
#         <p class="lyrics-section-label">[Bridge / Final Chorus]</p>
#         <p class="lyrics-line">< Paste the bridge and final chorus here ></p>
#
#         <p class="lyrics-note">You can replace each placeholder line with the actual lyrics of the song. All text in this block is centered for a clean, sing-along layout.</p>
#       </div>
#     </section>
#
#     <aside class="side-panel">
#       <div class="character-row">
#         <div class="character-card">
#           <div class="character-badge">Tree</div>
#           <div class="character-title">Christmas Tree</div>
#           <p class="character-text">Twinkling lights, ornaments, and a glowing star watching over your playlist.</p>
#         </div>
#         <div class="character-card">
#           <div class="character-badge">Bell</div>
#           <div class="character-title">Jingle Bells</div>
#           <p class="character-text">Soft chimes in the background as you hum your favorite chorus.</p>
#         </div>
#       </div>
#       <div class="character-row">
#         <div class="character-card">
#           <div class="character-badge">Rein</div>
#           <div class="character-title">Reindeer</div>
#           <p class="character-text">Dashing through the snow, carrying wishes across a winter sky.</p>
#         </div>
#         <div class="character-card">
#           <div class="character-badge">Santa</div>
#           <div class="character-title">Santa Claus</div>
#           <p class="character-text">Checking his list while your favorite song plays on repeat.</p>
#         </div>
#       </div>
#
#       <div class="cozy-footer">
#         Light a candle, grab a blanket, and let this page be the backdrop for your holiday soundtrack.
#       </div>
#     </aside>
#   </main>
# </div>
